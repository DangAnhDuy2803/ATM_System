# %%
#move_up của switch
def move_up(self):
    if self.state == "off":
        self.state = "wash"
    elif self.state == "wash":
        self.state = "wipe"

# %%
#change_state
def change_state(self):
    if self.state == "working":
        self.state = "notworking"
    else:
        self.state == "working"

# %%
#procedural
if fuse.is_working():
    if switch.state != "off":
        if relay.is_working():
            pump_status = "working"

# %%
#working
def working(self):
    self.status = self.relay.working()
    if self.status == "working":
        self.water_bottle.extract(self.status)
